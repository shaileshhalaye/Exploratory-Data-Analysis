# %% [markdown]
# 1. Iris
#
# 2. Tips
#
# 3. Titanic

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
#importing iris data from seaborn
iris=snr.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#dropping the species column (because categorical in nature)
data=iris.drop(['species'],axis=1) #axis=1 is used to drop the entire 'species' column

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
#line graph
ax=data.plot(figsize=(15,8),title='Iris Dataset')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
#histogram
data['petal_length'].diff().plot(kind='hist',bins=200) #bins represent the width of each histogram block

# %%
data['sepal_width'].diff().plot(kind='hist',bins=200)

# %%
data['sepal_length'].diff().plot(kind='hist',bins=200)

# %%
data['petal_width'].diff().plot(kind='hist',bins=200)

# %%
#bar graph
data.plot(kind='bar')

# %%
data.iloc[0:5].plot(kind='bar')

# %%
data.iloc[5].plot(kind='bar')

# %%
data.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaaab40cd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaaa9f2710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaaab407d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaaa9d3d50>],
#       dtype=object)

# %%
#pie chart
data.iloc[0].plot.pie(figsize=(10,10),fontsize=15,autopct='%.2f') #values inside the pie upto 2 decimal points

# %%
data.iloc[0:3].plot.pie(figsize=(10,10),subplots=True, fontsize=10,autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa96e00d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa95e4550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa9710c90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa96dcb90>],
#       dtype=object)

# %%
data.iloc[0:4].plot.pie(figsize=(10,10),subplots=True, fontsize=10,autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa99cefd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa98cd210>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa99cef10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa9692450>],
#       dtype=object)

# %%
#scatter plot
data.plot.scatter(x='sepal_length',y='petal_length',c='r') #'r' means red

# %%
data.plot.scatter(x='sepal_length',y='sepal_width',c='g') #'g' means green

# %%
data.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')

# %%
tips=snr.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#relational plot
snr.relplot(x='total_bill',y='tip',data=tips,hue='smoker')

# %%
snr.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')

# %%
snr.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',col='sex')

# %%
snr.relplot(x='total_bill',y='tip',data=tips,hue='smoker',col='time')

# %%
snr.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time',col='sex',size='size')

# %%
#catplot
snr.catplot(x='total_bill',y='day',data=tips)

# %%
#boxplot
snr.catplot(x='day',y='tip',hue='sex',kind='box',data=tips)

# %%
new_data=pd.read_csv("/content/Advertising.csv")

# %%
new_data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
my_data=new_data.drop(['Unnamed: 0'],axis=1)

# %%
my_data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
my_data.iloc[0:4].plot(kind='bar')

# %%
#pairplot
snr.pairplot(my_data,x_vars=['TV','Radio','Newspaper'],y_vars=['Sales'],size=15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
